# %% [markdown]
# <H1> Lab 8 </H1>

# %% [markdown]
# <H2> Function block </H2>

# %% [markdown]
# <H3>
# Draw plot
# </H3>

# %%
from re import A
from xml.etree.ElementTree import QName
import numpy as np
import math
import matplotlib.pyplot as plt
from sympy import Symbol, lambdify, diff, derive_by_array
from scipy import optimize
import pandas as pd

def plpl(foo, x: list[float],y: list[float]) -> list[float]:
    c =[]
    tmp = [1,1]
    for i in range(len(x)):
        #print(i)
        if i > 0:
            if abs(c[-1] - foo(x[i],y[i])) > 0.0000000001:     
                c.append(foo(x[i],y[i]))
        else:
            c.append(foo(x[i],y[i]))
            
    return c

def plpl1(foo, x: list[float],y: list[float]) -> list[float]:
    c =[]
    tmp = [1,1]
    for i in range(len(x)):
        #print(i)
        
        c.append(foo(x[i],y[i]))
    #с = set(c)
    #c.sort()
    #print(c)
    return c

def draw_counterplot(x_min, xk, flag, foo):
    fig, ax = plt.subplots(figsize = (5,5))

    x, y = np.linspace(min(xk[0]) - 1/2, max(xk[0]) + 1/2), np.linspace(min(xk[1]) - 1/2, max(xk[1]) + 1/2)
    
    x, y = np.meshgrid(x ,y)
    
    z = foo(x,y)

    v = plpl(foo, xk[0], xk[1])
    v.sort()
    # построим линии уровня
    ax.contour(x, y, z, levels = v)
    # траектория поиска точки минимума
    ax.plot(xk[0], xk[1], marker='o', markersize = 3, color = 'red')
    # подписи к осям
    ax.set_xlabel('$x$', fontsize = 12)
    ax.set_ylabel('$y$', fontsize = 12)
    #ax.set_title('Линии уровня и траектория поиска точки' , fontdict = {'fontsize' : 14})

    # создадим сетку 
    ax.grid(linestyle = '-')



    pass

def draw_counterplot8(x_min, xk, foo, flag):
    fig, ax = plt.subplots(figsize = (5,5))


    if flag == 0:
        x = [0, 10, 0, 0]
        y = [0, 0, 10, 0]
        ax.plot(x, y, marker="v", markersize = 3, color = "black")
        a = xk[0].copy()
        a.append(0)
        a.append(10)
        b = xk[1].copy()
        b.append(0)
        b.append(10)
    else:
        a = xk[0].copy()
        a.append(-3 + np.sqrt(40) * np.cos(math.pi))
        a.append(-3 + np.sqrt(40) * np.cos(0))
        b = xk[1].copy()
        b.append(-4 + np.sqrt(90) * np.sin(- math.pi / 2))
        b.append(-4 + np.sqrt(90) * np.sin(math.pi / 2))
        t = np.linspace(0, 2 * math.pi, 100)
        ax.plot( -3 + np.sqrt(40) * np.cos(t), -4 + np.sqrt(90) * np.sin(t) , color = "black")

    

    x, y = np.linspace(min(a) - 3.5, max(a) + 3.5), np.linspace(min(b) - 3.5, max(b) + 3.5)
    
    x, y = np.meshgrid(x ,y)
    
    z = foo(x,y)

    v = plpl(foo, xk[0], xk[1])
    v.sort()
    # построим линии уровня
    ax.contour(x, y, z, cmap = "BuPu")

    ax.contour(x, y, z, levels = v)

    # траектория поиска точки минимума
    ax.plot(xk[0], xk[1], marker='o', markersize = 3, color = 'red')


    # cond1 = lambda x, y: [-x, -y, (x + y - 10)]
    # cond2 = lambda x, y: [(x + 3)**2 / 4 + (y + 4)**2 / 9 - 10]

    # cond = cond1 if flag == 0 else cond2



    # подписи к осям
    ax.set_xlabel('$x$', fontsize = 12)
    ax.set_ylabel('$y$', fontsize = 12)
    #ax.set_title('Линии уровня и траектория поиска точки' , fontdict = {'fontsize' : 14})

    # создадим сетку 
    ax.grid(linestyle = '-')



    pass


def draw_plot(xk, foo, levels_mas):
    fig, ax = plt.subplots(figsize = (5,5))

    x, y = np.linspace(min(xk[0]) - 1/2, max(xk[0]) + 1/2), np.linspace(min(xk[1]) - 1/2, max(xk[1]) + 1/2)
    
    x, y = np.meshgrid(x ,y)
    
    z = foo(x,y)
    v = plpl(foo, levels_mas[0], levels_mas[1])
    v = list(set(v))
    v.sort()
    #print(v)
    # построим линии уровня
    ax.contour(x, y, z, levels = v)
    # траектория поиска точки минимума
    ax.plot(xk[0], xk[1], marker='o', markersize = 3, color = 'red')
    # подписи к осям
    ax.set_xlabel('$x$', fontsize = 12)
    ax.set_ylabel('$y$', fontsize = 12)
    #ax.set_title('Линии уровня и траектория поиска точки' , fontdict = {'fontsize' : 14})

    # создадим сетку 
    ax.grid(linestyle = '-')



    pass

def draw_counterplot1(x_min, xk, A, flag, foo):
    fig, ax = plt.subplots(figsize = (5,5))

    x, y = np.linspace(min(xk[0]) - 1/2, max(xk[0]) + 1/2), np.linspace(min(xk[1]) - 1/2, max(xk[1]) + 1/2)
    
    x, y = np.meshgrid(x ,y)
    
    z = foo(x,y)

    v = plpl(foo, xk[0], xk[1])
    v = list(set(v))
    v.sort()

    #print(v)
    # построим линии уровня
    ax.contour(x, y, z, levels = v)
    # траектория поиска точки минимума
    ax.plot(xk[0], xk[1], marker='o', markersize = 3, color = 'red')

    for k in range(1,len(A[0])):
        
        ax.plot ([A[0][k-1],A[0][k]], [A[1][k-1],A[1][k]], marker='o', markersize = 3, color = 'green')
        #ax.plot (A[0][k], A[1][k], marker='o', markersize = 3, color = 'green')


    # подписи к осям
    ax.set_xlabel('$x$', fontsize = 12)
    ax.set_ylabel('$y$', fontsize = 12)
    #ax.set_title('Линии уровня и траектория поиска точки' , fontdict = {'fontsize' : 14})

    # создадим сетку 
    ax.grid(linestyle = '-')



    pass

def draw_all(x0, x_min, xk, flag, foo, ang_a = 20, ang_b = 145):

    fig = plt.figure(figsize = (15, 5), dpi=120)

    ax1 = fig.add_subplot(1, 2, 1, projection='3d')
    ax2 = fig.add_subplot(1, 2, 2)
    #ax3 = fig.add_subplot(1, 3, 3)
    plt.subplots_adjust(wspace=0.7)

    coef = max(abs(x0[0] - x_min[0]), abs(x0[1]-x_min[1]))
    #coef = max(abs( min(xk[0]) - x_min[0]), abs(min(xk[1])-x_min[1]))
    x, y = np.meshgrid(np.linspace(x_min[0] - coef, x_min[0] + coef, 100),np.linspace(x_min[1] - coef, x_min[1] + coef, 100))
    z = foo(x, y)

    v = plpl(foo, xk[0], xk[1])
    v.sort()
    

    ax1.plot_surface(x,y,z, cmap = 'plasma', alpha = 0.5)
    ax1.contour3D(x,y,z, 120, cmap = 'plasma', alpha = 0.3)
    ax1.contour3D(x,y,z, levels = v, colors = 'black', alpha = 0.5) #cmap = 'tab20')

    v = plpl1(foo, xk[0], xk[1])
    
    ax1.plot(xk[0], xk[1], v, marker='o', markersize = 3, color = 'red')

    ax1.scatter(xk[0][0], xk[1][0], foo(xk[0][0], xk[1][0]), s = 20, c = 'green', label="$x_{beg}$ - точка начального приближения")
    ax1.scatter(x_min[0], x_min[1], foo(x_min[0], x_min[1]), s = 20, c = 'red', label="$x_{min}$ - точка минимума")
    ax1.legend(shadow=True, fontsize=8)
    ax1.view_init(ang_a, ang_b)
    ax1.set_xlabel('$x$', fontsize = 12)
    ax1.set_ylabel('$y$', fontsize = 12)
    ax1.set_zlabel('$z$', fontsize = 12)
    ax1.set_title('График поверхности функции', fontdict = {'fontsize' : 14})


    #x, y = np.meshgrid(xk[0], xk[1])
    x, y = np.linspace(min(xk[0]) - 1/2, max(xk[0]) + 1/2), np.linspace(min(xk[1]) - 1/2, max(xk[1]) + 1/2)
    
    x, y = np.meshgrid(x ,y)
    
    z = foo(x,y)

    v = plpl(foo, xk[0], xk[1])
    v.sort()
    # построим линии уровня
    ax2.contour(x, y, z, v)
    # траектория поиска точки минимума
    ax2.plot(xk[0], xk[1], marker='o', markersize = 3, color = 'red')
    # подписи к осям
    ax2.set_xlabel('$x$', fontsize = 12)
    ax2.set_ylabel('$y$', fontsize = 12)
    ax2.set_title('Линии уровня и траектория поиска точки' , fontdict = {'fontsize' : 14})

    # создадим сетку 
    ax2.grid(linestyle = '-')

    # k = range(len(w_norm))
    # #x, y = np.meshgrid(k , w_norm)
    # ax3.plot(k, w_norm)
    # ax3.set_xlabel('$k$')
    # ax3.set_ylabel('$ \| \! \| w_k \| \! \| $')
    # ax3.set_title('Зависимость нормы \n антиградиента $ \| \! \| w_k \| \! \| $ от параметра $k$')



    pass

# %% [markdown]
# <H3> Golden Ratio </H3>

# %%
import numpy as np
import math
eps = 10**(-2)
def method_goldenRatio(f, b: float = 1, a: float = 0, e = eps * 1e-1):
    tau = (math.sqrt(5) + 1) / 2
    n_f = 0
    Ak, Bk = a, b
    lk = Bk - Ak
    Xk1 = Bk - (Bk - Ak) / tau
    Xk2 = Ak + (Bk - Ak) / tau
    y1, y2 = f(Xk1), f(Xk2)
    
    n_f += 2

    while lk >= e:
        if y1 < y2:
            Bk = Xk2
            Xk2 = Xk1
            Xk1 = Ak + Bk - Xk2
            y2 = y1
            y1 = f(Xk1)
            n_f += 1 
        else:
            
            Ak = Xk1
            Xk1 = Xk2
            Xk2 = Ak + Bk - Xk1
            y1 = y2
            y2 = f(Xk2)
            n_f += 1
            
        lk = Bk - Ak
    return (Ak + Bk) / 2, n_f

# %% [markdown]
# <H2> lab8 optimization

# %% [markdown]
# <h3> Straigth optimization

# %%
from cmath import sqrt
import numpy as np
import math
import matplotlib.pyplot as plt
from sympy import Symbol, lambdify, diff, derive_by_array
from scipy import optimize

x0 = [-1, -2]
e = 10 ** (-16)
def vec_rav(a, b) -> bool:
    for i in range(len(a)):
        if a[i] != b[i]:
            return False
    return True
    
def straight_optimization(foo, eps = e, x = np.array(x0), flag: int = 0, flag1: int = 0, n_dim: int = 2):

    n_f = 0
    n_g = 0
    n_d = 0

    #foo = lambda x, y: fff([x, y])

    golden_param = 2.7
    beta_k = 1    
    x = np.array(x)
    
    f = lambda x: foo(x[0], x[1])

    xk = [[],[]]
    xk[0].append(x[0])
    xk[1].append(x[1])

    n = n_dim #hess.ndim #момент обновления алгоритма
    basis = np.identity(n_dim)

    x_prev = x
    b = np.array([1/2, 1/2])
    gamma = 0.5

    pk = np.copy(basis)

    while True:
        n_d += 1        
        
        #циклический покоординатный спуск
        if flag == 0:
            x_prev = x

            for j in range(n):
                ej = basis[j]
                phi_k = lambda beta: f(x + beta * ej)
                temp = 0 
                beta_k, temp = method_goldenRatio(phi_k, golden_param, -golden_param, eps/1000)
                #beta_k, nnn, temp = optimize.golden(phi_k, full_output=True) 
                n_f += temp
                x = x + beta_k * ej
                xk[0].append(x[0])
                xk[1].append(x[1])
            
            if  np.linalg.norm(x - x_prev) < eps:
                break
        
        #метод Хука-Дживса        
        elif flag == 1:

            if xk[0][-1] != x[0] and xk[1][-1] != x[1]:
                xk[0].append(x[0])
                xk[1].append(x[1])

            x_save = x_prev
            x_prev = x
            xj = x_prev

            for j in range(n):
                
                ej = basis[j]

                fj = f(xj)
                f_plus_j = f(xj + b[j] * ej)
                f_minus_j = f(xj - b[j] * ej)

                if f_plus_j < fj and f_plus_j <= f_minus_j:
                    xj = xj + b[j] * ej
                elif f_minus_j < fj and f_plus_j > f_minus_j:
                    xj = xj - b[j] * ej 

                if xk[0][-1] != xj[0] and xk[1][-1] != xj[1]:
                    xk[0].append(xj[0])
                    xk[1].append(xj[1])
                    # basis_iter_mas[0].append(xj[0])
                    # basis_iter_mas[1].append(xj[1])

            if vec_rav(xj, x_prev):
                b = gamma * b
                x = x_prev
                x_prev = x_save 
                if np.linalg.norm(b) < eps / 1000:
                    break
            else:  

                if np.linalg.norm(xj - x_prev) < eps:
                    break
            
                x = xj 
                phi_k = lambda a_k: f(x_prev + a_k * (xj - x_prev))
                temp = 0 
                #a_k, temp = method_goldenRatio(phi_k, 1, 0, eps/1000)
                #a_k, temp = method_goldenRatio(phi_k, 4, -4, eps/100)
                a_k, nnn, temp = optimize.golden(phi_k, brack=(0,1), full_output=True) 
                n_f += temp                
                x = x_prev + a_k * (xj - x_prev)

                if xk[0][-1] != x[0] and xk[1][-1] != x[1]:
                    xk[0].append(x[0])
                    xk[1].append(x[1])
                

            if np.linalg.norm(x - x_prev) < eps:
                break
        
        #метод Розенброка
        if flag == 2:
            
            x_prev = x
            xj = x

            kappa_mas = []
            aj_mas = []
            bj_mas = []


            for j in range(n):

                phi = lambda kappa: f(xj+ kappa * pk[j])
                temp = 0
                #kappa, temp = method_goldenRatio(phi, 5, -5, eps/100)
                kappa, nnn, temp = optimize.golden(phi, full_output=True, maxiter=100)
                n_f += temp
                xj = xj + kappa * pk[j]
                kappa_mas.append(kappa)

            x = xj            
            xk[0].append(x[0])
            xk[1].append(x[1])

            if np.linalg.norm(x - x_prev) < eps:
                break
            
            for j in range(n):
                tmp = np.array([0,0])
                if kappa_mas[j] == 0:
                    aj_mas.append(pk[j])
                else:
                    for i in range(j,n):
                        tmp = tmp + kappa_mas[i] * pk[i]                        
                    aj_mas.append(tmp)
                    #print(aj_mas)
            
            for j in range(n):
                tmp = np.copy(aj_mas[j])
                if j == 0:
                    bj_mas.append(aj_mas[j])
                else:
                    for i in range(0, j-1):
                        tmp = tmp - np.dot(aj_mas[j], pk[i]) * pk[i]
                    bj_mas.append(tmp)
            
            for j in range(n):
                pk[j] = 1 / np.linalg.norm(bj_mas[j]) * bj_mas[j]
        
            # else:
            #     x = xj
            #     xk[0].append(x[0])
            #     xk[1].append(x[1])
            #     if np.linalg.norm(x - x_prev) < eps:
            #         break
                

    # if flag == 1:
    #     return x, xk, basis_iter_mas, n_f, n_d

    return x, n_f, n_d

# %% [markdown]
# <h2>Method Newton

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from sympy import Symbol, lambdify, diff, derive_by_array
from scipy import optimize

x0 = [-1, -2]
e = 10 ** (-2)

def newton_method(foo, eps = e, x = np.array(x0), flag: int = 0, flag1: int = 0):

    n_f = 0
    n_g = 0
    n_d = 0

    kappa_k = 1
    kappa_max = 25
    

    #foo = lambda x, y: fff([x,y])

    x = np.array(x)

    x_, y_ = Symbol('x'), Symbol('y')
    grad_f = lambdify((x_, y_), derive_by_array(foo(x_, y_), (x_, y_)), 'numpy')
    #print(grad_f(x[0],x[1]))
    
    
    f = lambda x: foo(x[0], x[1])
    
    grad = lambda x: grad_f(x[0], x[1])

    anti_grad = lambda x: np.array(-grad_f(x[0], x[1]))
    
    xk = [[],[]]
    xk[0].append(x[0])
    xk[1].append(x[1])

    h = lambdify((x_, y_), [[diff(foo(x_, y_), x_, 2), diff(foo(x_, y_), x_, y_)], [diff(foo(x_, y_), y_, x_), diff(foo(x_, y_), y_, 2)]], 'numpy')
    H = lambda x: np.array(h(x[0],x[1]))  

    n = 2 #hess.ndim #момент обновления алгоритма
    Ak = np.identity(n)

    w_norm = []    
    wk = np.array(anti_grad(x))
    n_g += 1
    w_norm.append(np.linalg.norm(wk))

    x_prev = x
    wk_prev = wk
    
    n_update = n
    n_update_counter = 1
    while w_norm[-1] > eps:

        n_d += 1
        
        pk = Ak.dot(wk)     

        phi_k = lambda kappa: f(x + kappa * pk)

        temp = 0 
        if flag1 == 0:       
            kappa_k, temp = method_goldenRatio(phi_k, 0.5, 0, eps/1000)
        else:
            kappa_k, nnn, temp = optimize.golden(phi_k, full_output=True)      


        n_f += temp

        x = x + kappa_k * pk
        wk = anti_grad(x)
        n_g += 1

        w_norm.append(np.linalg.norm(wk))
        xk[0].append(x[0])
        xk[1].append(x[1])
        
        if n_d % n_update == 13531:
            Ak = np.identity(n)
            n_update_counter += 1
            n_update =  n * n_update_counter

        else:
            dx = x - x_prev
            dx_m = np.array([[dx[0], 0], [dx[1], 0]])
            dw = wk - wk_prev
            dw_m = np.array([[dw[0], 0], [dw[1], 0]])

            if flag == 0: #DFP
                dA =  - ( dx_m.dot(dx_m.T) / (dw.dot(dx)) + (Ak.dot(dw_m.dot(dw_m.T.dot(Ak.T)))) / np.dot(Ak.dot(dw), dw) )          
                #print(f' d 1 = {(dx_m.dot(dx_m.T) / (dw.dot(dx)))}')
                
                #print(f' d 2 = {(Ak.dot(dw_m.dot(dw_m.T.dot(Ak.T)))) / np.dot(Ak.dot(dw), dw)}')
                #print(dA)
                #print((Ak.dot(dw_m.dot(dw_m.T.dot(Ak.T)))) / np.dot(Ak.dot(dw), dw))
            elif flag == 1: #BFSh                
                ro_k = np.dot(Ak.dot(dw), dw)
                r_k = (Ak.dot(dw) / ro_k ) - (dx / (dx.dot(dw)))                
                r_k_m = np.array([[r_k[0], 0],[r_k[1], 0]])
                dA =  -( dx_m.dot(dx_m.T) / (dw.dot(dx)) + (Ak.dot(dw_m.dot(dw_m.T.dot(Ak.T)))) / np.dot(Ak.dot(dw), dw) )          
                dA = dA + ro_k * (r_k_m.dot(r_k_m.T))            
            
            elif flag == 2: #Paul
                tmp = (dx + Ak.dot(dw))
                tmp_m = np.array([[tmp[0], 0], [tmp[1], 0]])
                dA = - ( tmp_m.dot(tmp_m.T) / (dw.dot(tmp)))
                
            Ak = Ak + dA 
        #print(f'pk = {pk} \n wk = {wk} \n A = {Ak} \n ')
        x_prev = x
        wk_prev = wk
        
    return x

# %% [markdown]
# <h3> Lab8

# %%
from sympy import Symbol

x_, y_ = Symbol('x'), Symbol('y')
cond1 = lambdify( (x_, y_), [1/-x_, 1/-y_, 1/ (x_ + y_ - 10)])


print(sum(cond1(x_,y_)))
# Out:
# (x + y - 10)**(-1.0) - 1/y - 1/x

# %%
from cmath import sqrt
import numpy as np
import math
import matplotlib.pyplot as plt
from sympy import Symbol, lambdify, diff
from sympy.tensor.array import derive_by_array
from scipy import optimize


def lab8_methods(foo, eps = e, x = np.array(x0), flag: int = 0, flag1: int = 0):

    n_f = 0
    n_d = 0

    x = np.array(x)


    rk = 8

    
    
    #fk = lambda x, y: f(x, y) + rk * (g1(x, y) + g2(x, y) + g3(x, y))

    xk = [[],[]]
    xk[0].append(x[0])
    xk[1].append(x[1])

    n = 2
    C = 10

    from sympy import Symbol

    x_, y_ = Symbol('x'), Symbol('y')
    #cond1 = lambdify( (x_, y_), [1/-x_, 1/-y_, 1/ (x_ + y_ - 10)])
    #cond2 = lambdify( (x_, y_), (x_ + 3)**2 / 4 + (y_ + 4)**2 / 9 - 10)
    
    cut = lambda x: np.piecewise(x, [x<=0, x>0], [0, 1/x])
    cut2 = lambda x: x if x > 0 else 0

    #g1 = lambda x: np.piecewise(x, [x > 0, x <= 0], [-1/x, -10**(100)])

    if flag == 0:
        def g1(x):
            if x > 0:
                return - 1 / x
            else:
                return - (10 ** 100)
        
        def g3(x, y):
            if x + y < 10:
                return 1 / (x + y - 10)
            else:
                return - (10 ** 100)
        
        def g4(x, y):
            return 0.5 * ( abs( (x + 3)**2 / 4 + (y + 4)**2 / 9 - 10 ) +  (x + 3)**2 / 4 + (y + 4)**2 / 9 - 10 )
    
    else:
        def g1(x):
            return abs(-x) - x
        
        def g3(x, y):
            return 0.5 * ( abs( x + y - 10) + x + y - 10)
        
        def g4(x, y):
            return 0.5 * ( abs( (x + 3)**2 / 4 + (y + 4)**2 / 9 - 10 ) +  (x + 3)**2 / 4 + (y + 4)**2 / 9 - 10 )
    

    # cond1 = lambda x, y: [-x, -y, -(x + y - 10)]
    # cond2 = lambda x, y: [((x + 3)**2 )/ 4 + ( (y + 4)**2 ) / 9 - 10]

    # cond = cond1 if flag1 == 0 else cond2

    # print(cond(x_,y_))
    
    fk2 = foo(x[0],x[1])

    while True:
        n_d += 1

        if flag == 0:            
            def curr_func(x, y):
                if flag1 == 0:
                    return foo(x, y) - rk * (g1(x) + g1(y) + g3(x, y))
                else:
                    return foo(x, y) + rk * (g4(x,y))
        else:
            def curr_func(x, y):
                if flag1 == 0:
                    return foo(x, y) + rk * (g1(x) + g1(y) + g3(x,y))
                else:
                    return foo(x, y) + rk * g4(x, y)

        #print(curr_func(x_, y_))
        #x = newton_method(curr_func, eps, x, 1, 0)
        x, temp1, temp2 = straight_optimization(curr_func, eps, x, 2)
        n_f += temp1

        fk1 = fk2
        fk2 = curr_func(x[0],x[1])
        n_f += 1
        
        if flag == 0:
            rk /= 2
        else:
            rk *= 2
        
        if abs(fk1 - fk2) < eps:
            break

        xk[0].append(x[0])
        xk[1].append(x[1])

    return x, xk, n_f, n_d

# %%
from functools import reduce
import numpy as np
B = np.array([[1/2, 0], [-1 , 0]])#
C = np.array([1/2,-1])
R = np.array([1/2,1])
#print(np.dot(C, B), np.dot(B.T, C))
#print(B.dot(B.T))
#r = np.ones(2, 4)
#print(r)
#x = np.zeros(2)
basis = []
print(type(basis))

n_dim = 2
# for i in range(n_dim):
#         e = [0] * (n_dim - 1)
#         e.insert(i, 1)
#         basis.append(np.array(e))

basis = np.identity(n_dim)
print(basis[0])
print(vec_rav(C, R))
b = np.array([2, 3])
b = 0.8 * b 
# 

#print(np.dot(C, T))
#np.matrix.transpose(C)

y = np.copy(C)
#y = C

y[1] = 0

for i in range(1,3+1):
    print(i)

n = 2
x_simplex = np.zeros((3, 2))
print(x_simplex)
# Out:
# <class 'list'>
# [1. 0.]
# False
# 1
# 2
# 3
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %% [markdown]
# <H3> Print function </H3>

# %%
from sympy import Symbol, lambdify, diff, derive_by_array
from scipy import optimize
import math

#x0 = [-1,-2]
def print_res(foo, x0 = x0, e_help = 2, flag = 0):

    #tabledata = []

    x_, y_ = Symbol('x'), Symbol('y')
    eps = 10**(-e_help)

    print("\n", ' ' * 30, "Методы штрафных функций","\n")
    print("Дано:")
    print("-" * 24)
    print("      Целевая функция:    f(x, y) =", foo(x_,y_))
    print("Начальное приближение:    (x, y) =", x0)
    print(" Точность приближения:    eps =", eps)
    print("-" * 24)



    for i in range (2):
        #temp = []
        #print("\n" + "_" * 80)

        if i == 0:
            method_name = "Метод внутренних штрафных функций"
            print("\n", ' ' * 30, f"{method_name} \n")

        elif i == 1:
            method_name = "Метод внешних штрафных функций"
            print("\n", ' ' * 30, f"{method_name} \n")
            
        if flag == 0:
            print("\n", ' ' * 30, f"на можестве A \n")
        else:
            print("\n", ' ' * 30, f"на множестве B \n")
        
        #x_min, xk, w_norm, n_f, n_g , n_d = straight_optimization(foo, eps, x0, i, flag1)
        x_min, xk, n_f, n_d = lab8_methods(foo, eps, x0, i, flag)
        
        print("             Точка минимума функции:     x_min =", [round(x_min[0], e_help), round(x_min[1], e_help)])
        print("  Значение функции в точке минимума:  f(x_min) =", round(foo(x_min[0], x_min[1]), e_help))
        print("                Количество итераций:         k =",   n_d)#len(w_norm) - 1)
        print("      Количество вычислений функции:       n_f =", n_f)
        #print("  Количество вычисленных градиентов:       n_g =", n_g)
        #print("Количество вычисленных матриц Гессе:    n_hess =", n_hess)
        draw_counterplot8(x_min, xk,  foo, flag)
        

        #print(xk)
        #draw_counterplot_only(x_min, xk, w_norm, i, fk)
        plt.show()
    
    #a = print_tables(tabledata)


    pass

# %%
import numpy as np
import math

alpha = 5
#foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
foo = lambda x, y: 5*x**2 + 4* x * y + 2 * y**2 + 4 * math.sqrt(5) * (x +  y) -35

#foo = lambda x, y: 5*x**2 + 4* x * y + 8 * y**2 + 8 * math.sqrt(5) * (2*x +  y) -44

#foo = lambda x, y: 5*x**2 + 4* x * y + 2 * y**2 + 4 * math.sqrt(5) * (x +  y) +51
#foo = lambda x, y: 6*x**2 - 4* x * y + 3 * y**2 + 4 * math.sqrt(5) * (x +  2* y) +22
# h = lambdify((x_, y_), [[diff(foo(x_, y_), x_, 2), diff(foo(x_, y_), x_, y_)], [diff(foo(x_, y_), y_, x_), diff(foo(x_, y_), y_, 2)]], 'numpy')
# H = lambda x: np.array(h(x[0],x[1]))

#x0 = np.array([4, 2.5])
#x0 = np.array([0.1, 0.1])
#x0 = np.array([-7, 0])
#
# 
#x0 = np.array([5, 2])
#
# 
#x0 = np.array([2, -2])

#x0 = np.array([-4, -8])



x_min, xk,  n_f, n_d = lab8_methods(foo, 0.000001, x0, 0, 0)
print(x_min, foo(x_min[0], x_min[1]), n_d, n_f)
draw_counterplot8(x_min, xk, foo, 0)

x_min, xk,  n_f, n_d = lab8_methods(foo, 0.000001, x0, 0, 1)
print(x_min, foo(x_min[0], x_min[1]), n_d, n_f)
draw_counterplot8(x_min, xk, foo, 1)

x_min, xk,  n_f, n_d = lab8_methods(foo, 0.000001, x0, 1, 0)
print(x_min, foo(x_min[0], x_min[1]), n_d, n_f)
draw_counterplot8(x_min, xk, foo, 0)

x_min, xk,  n_f, n_d = lab8_methods(foo, 0.000001, x0, 1, 1)
print(x_min, foo(x_min[0], x_min[1]), n_d, n_f)
draw_counterplot8(x_min, xk, foo, 1)

# print_res(foo, x0, 2, 0)
# print_res(foo, x0, 2, 1)


#print_res(foo, x0, 2, 0)
#print(levels_mass)
#draw_all(x0, x_min, xk, 0, foo, 30, -20)
#draw_plot(xk, foo, levels_mass)
#print(xk)
#draw_all(x0, x_min, xk, w_norm, 0, foo, 45, 170)

#print(xk)
# alpha = 200
# foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2

# print_res(foo, x0, 2)
# Out:
# [5.63739484e-08 5.63714735e-08] -34.99999899157426 49 17356
# [ 3.36037120e-08 -2.23606795e+00] -44.99999999999999 2 672
# [8.79568156e-16 3.12047749e-16] -34.99999999999999 2 583
# [ 2.44710825e-08 -2.23606795e+00] -45.0 2 678

# %% [markdown]
# <H3> Make pandas.DateFrame </H3>

# %%
import pandas as pd

def make_df(tabledata) -> pd.DataFrame:
        df = pd.DataFrame(tabledata, columns = ['Тип функции', 'Начальная точка', 'Точность', 'Метод', 'Точка минимума функции', 'Значение функции в точке минимума', 'Количество итераций', 'Количество вычислений функции'])#, 'Количество вычисленных градиентов']) #, 'Количество вычисленных матриц Гессе' ])
        return df

# %% [markdown]
# <H3> Make sheets</H3>

# %%
from sympy import Symbol, lambdify, diff, derive_by_array
from scipy import optimize

#x0 = [-1,-2]
def make_sheets(foo, f_type, x0_mass = [[-1, -2]],  e_help = 2, tabledata = [], flag: int = 0):

    nu = 0.8
    omega = 0.5
    eps = 10**(-e_help)
    x0 = x0_mass[0]

    if f_type == 0:
        func_name = 'Квадратичная функция'
    else:
        func_name = 'Функция Розенброка'
    

    for j in range(len(x0_mass)):
        
        x0 = x0_mass[j]
        
        for i in range (2):
            
            if i == 0:
                method_name = "Метод внутренних штрафных функций"
                
            elif i == 1:
                method_name = "Метод внешних штрафных функций"
                
            x_min, xk, n_f, n_d = lab8_methods(foo, eps, x0, i, flag)
            
            temp = [func_name, x0, round(eps, e_help), method_name, [ round(x_min[0], e_help), round(x_min[1], e_help)], round(foo(x_min[0], x_min[1]), e_help), n_d, n_f] 
            tabledata.append(temp)
            
    return tabledata

# %% [markdown]
# <H2>
# Calculations
# </H2>

# %% [markdown]
# <H3> Sheets </H3>

# %%
from secrets import randbelow
from tkinter import font


styles = [dict(selector="caption", props=[("text-align", "center"), ("font-size", "150%")])]

e_help = 2
x0 = np.array([4, 2.5])

x0_mass = [[4, 2.5], [0.1, 0.1], [-7, 0], [5, 2], [-2, 2]]

#foo = lambda x, y: 5*x**2 + 4* x * y + 2 * y**2 + 4 * math.sqrt(5) * (x +  y) -35

foo = lambda x, y: 5*x**2 + 4* x * y + 2 * y**2 + 4 * math.sqrt(5) * (x +  y) -35
tabledata1 = []
for i in range(2):
    if i == 0:
        e_help = 2
    else: 
        e_help = 6
    make_sheets(foo, 0, [[-2, 2]], e_help, tabledata1, 1)
alpha = 5
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
for i in range(2):
    if i == 0:
        e_help = 2
    else: 
        e_help = 6
    make_sheets(foo, 1, [[-2, 2]], e_help, tabledata1, 1)
alpha = 50
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
for i in range(2):
    if i == 0:
        e_help = 2
    else: 
        e_help = 6
    make_sheets(foo, 1, [[-2, 2]], e_help, tabledata1, 1)
# Результаты вычислений квадратичной функции в зависимости от начальной точки
#make_sheets(foo, 0, x0_mass, e_help, tabledata1)
df1 = make_df(tabledata1)



alpha = 5
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
tabledata2 = [] # Результаты вычислений функции Розенброка в зависимости от начальной точки
make_sheets(foo, 1, x0_mass, e_help, tabledata2)
df2 = make_df(tabledata2)


alpha = 50
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
tabledata2 = [] # Результаты вычислений функции Розенброка в зависимости от начальной точки
#make_sheets(foo, 1, x0_mass, e_help, tabledata2)
make_sheets(foo, 1, x0_mass, e_help, tabledata2, 1)
df3 = make_df(tabledata2)

alpha = 50
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
tabledata3 = [] # Результаты вычислений функции Розенброка в зависимости от заданной точности

for i in range(2):
    if i == 0:
        e_help = 2
    else: 
        e_help = 6
    make_sheets(foo, 1, [[-1,-2]], e_help, tabledata3)

df4 = make_df(tabledata3)

# %%
#df1 = df1.sort_values('Метод')

df1.style.set_caption('Результаты вычислений квадратичной функции в зависимости от начальной точки').set_table_styles(styles)
# Out:
# <style type="text/css">
# #T_ceabf caption {
#   text-align: center;
#   font-size: 150%;
# }
# </style>
# <table id="T_ceabf">
#   <caption>Результаты вычислений квадратичной функции в зависимости от начальной точки</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ceabf_level0_col0" class="col_heading level0 col0" >Тип функции</th>
#       <th id="T_ceabf_level0_col1" class="col_heading level0 col1" >Начальная точка</th>
#       <th id="T_ceabf_level0_col2" class="col_heading level0 col2" >Точность</th>
#       <th id="T_ceabf_level0_col3" class="col_heading level0 col3" >Метод</th>
#       <th id="T_ceabf_level0_col4" class="col_heading level0 col4" >Точка минимума функции</th>
#       <th id="T_ceabf_level0_col5" class="col_heading level0 col5" >Значение функции в точке минимума</th>
#       <th id="T_ceabf_level0_col6" class="col_heading level0 col6" >Количество итераций</th>
#       <th id="T_ceabf_level0_col7" class="col_heading level0 col7" >Количество вычислений функции</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceabf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ceabf_row0_col0" class="data row0 col0" >Квадратичная функция</td>
#       <td id="T_ceabf_row0_col1" class="data row0 col1" >[-2, 2]</td>
#       <td id="T_ceabf_row0_col2" class="data row0 col2" >0.010000</td>
#       <td id="T_ceabf_row0_col3" class="data row0 col3" >Метод внешних штрафных функций</td>
#       <td id="T_ceabf_row0_col4" class="data row0 col4" >[0.0, -2.24]</td>
#       <td id="T_ceabf_row0_col5" class="data row0 col5" >-45.000000</td>
#       <td id="T_ceabf_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_ceabf_row0_col7" class="data row0 col7" >646</td>
#     </tr>
#     <tr>
#       <th id="T_ceabf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ceabf_row1_col0" class="data row1 col0" >Квадратичная функция</td>
#       <td id="T_ceabf_row1_col1" class="data row1 col1" >[-2, 2]</td>
#       <td id="T_ceabf_row1_col2" class="data row1 col2" >0.000001</td>
#       <td id="T_ceabf_row1_col3" class="data row1 col3" >Метод внешних штрафных функций</td>
#       <td id="T_ceabf_row1_col4" class="data row1 col4" >[0.0, -2.236068]</td>
#       <td id="T_ceabf_row1_col5" class="data row1 col5" >-45.000000</td>
#       <td id="T_ceabf_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_ceabf_row1_col7" class="data row1 col7" >646</td>
#     </tr>
#     <tr>
#       <th id="T_ceabf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ceabf_row2_col0" class="data row2 col0" >Функция Розенброка</td>
#       <td id="T_ceabf_row2_col1" class="data row2 col1" >[-2, 2]</td>
#       <td id="T_ceabf_row2_col2" class="data row2 col2" >0.010000</td>
#       <td id="T_ceabf_row2_col3" class="data row2 col3" >Метод внешних штрафных функций</td>
#       <td id="T_ceabf_row2_col4" class="data row2 col4" >[1.0, 1.0]</td>
#       <td id="T_ceabf_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_ceabf_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_ceabf_row2_col7" class="data row2 col7" >1441</td>
#     </tr>
#     <tr>
#       <th id="T_ceabf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ceabf_row3_col0" class="data row3 col0" >Функция Розенброка</td>
#       <td id="T_ceabf_row3_col1" class="data row3 col1" >[-2, 2]</td>
#       <td id="T_ceabf_row3_col2" class="data row3 col2" >0.000001</td>
#       <td id="T_ceabf_row3_col3" class="data row3 col3" >Метод внешних штрафных функций</td>
#       <td id="T_ceabf_row3_col4" class="data row3 col4" >[1.0, 1.0]</td>
#       <td id="T_ceabf_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_ceabf_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_ceabf_row3_col7" class="data row3 col7" >1656</td>
#     </tr>
#     <tr>
#       <th id="T_ceabf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ceabf_row4_col0" class="data row4 col0" >Функция Розенброка</td>
#       <td id="T_ceabf_row4_col1" class="data row4 col1" >[-2, 2]</td>
#       <td id="T_ceabf_row4_col2" class="data row4 col2" >0.010000</td>
#       <td id="T_ceabf_row4_col3" class="data row4 col3" >Метод внешних штрафных функций</td>
#       <td id="T_ceabf_row4_col4" class="data row4 col4" >[1.0, 1.0]</td>
#       <td id="T_ceabf_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_ceabf_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_ceabf_row4_col7" class="data row4 col7" >2492</td>
#     </tr>
#     <tr>
#       <th id="T_ceabf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ceabf_row5_col0" class="data row5 col0" >Функция Розенброка</td>
#       <td id="T_ceabf_row5_col1" class="data row5 col1" >[-2, 2]</td>
#       <td id="T_ceabf_row5_col2" class="data row5 col2" >0.000001</td>
#       <td id="T_ceabf_row5_col3" class="data row5 col3" >Метод внешних штрафных функций</td>
#       <td id="T_ceabf_row5_col4" class="data row5 col4" >[1.0, 1.0]</td>
#       <td id="T_ceabf_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_ceabf_row5_col6" class="data row5 col6" >2</td>
#       <td id="T_ceabf_row5_col7" class="data row5 col7" >2697</td>
#     </tr>
#   </tbody>
# </table>

# %%
df2 = df2.sort_values('Начальная точка')

df2.style.set_caption('Результаты вычислений функции Розенброка в зависимости от начальной точки, alpha = 5').set_table_styles(styles)
# Out:
# <style type="text/css">
# #T_442a5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# </style>
# <table id="T_442a5">
#   <caption>Результаты вычислений функции Розенброка в зависимости от начальной точки, alpha = 5</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_442a5_level0_col0" class="col_heading level0 col0" >Тип функции</th>
#       <th id="T_442a5_level0_col1" class="col_heading level0 col1" >Начальная точка</th>
#       <th id="T_442a5_level0_col2" class="col_heading level0 col2" >Точность</th>
#       <th id="T_442a5_level0_col3" class="col_heading level0 col3" >Метод</th>
#       <th id="T_442a5_level0_col4" class="col_heading level0 col4" >Точка минимума функции</th>
#       <th id="T_442a5_level0_col5" class="col_heading level0 col5" >Значение функции в точке минимума</th>
#       <th id="T_442a5_level0_col6" class="col_heading level0 col6" >Количество итераций</th>
#       <th id="T_442a5_level0_col7" class="col_heading level0 col7" >Количество вычислений функции</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_442a5_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_442a5_row0_col0" class="data row0 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row0_col1" class="data row0 col1" >[-10, 18]</td>
#       <td id="T_442a5_row0_col2" class="data row0 col2" >0.010000</td>
#       <td id="T_442a5_row0_col3" class="data row0 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_442a5_row0_col4" class="data row0 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_442a5_row0_col6" class="data row0 col6" >1078</td>
#       <td id="T_442a5_row0_col7" class="data row0 col7" >229234</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_442a5_row1_col0" class="data row1 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row1_col1" class="data row1 col1" >[-10, 18]</td>
#       <td id="T_442a5_row1_col2" class="data row1 col2" >0.010000</td>
#       <td id="T_442a5_row1_col3" class="data row1 col3" >Метод внешних штрафных функций</td>
#       <td id="T_442a5_row1_col4" class="data row1 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_442a5_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_442a5_row1_col7" class="data row1 col7" >1690</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_442a5_row2_col0" class="data row2 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row2_col1" class="data row2 col1" >[-2, 5]</td>
#       <td id="T_442a5_row2_col2" class="data row2 col2" >0.010000</td>
#       <td id="T_442a5_row2_col3" class="data row2 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_442a5_row2_col4" class="data row2 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_442a5_row2_col6" class="data row2 col6" >79</td>
#       <td id="T_442a5_row2_col7" class="data row2 col7" >17517</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_442a5_row3_col0" class="data row3 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row3_col1" class="data row3 col1" >[-2, 5]</td>
#       <td id="T_442a5_row3_col2" class="data row3 col2" >0.010000</td>
#       <td id="T_442a5_row3_col3" class="data row3 col3" >Метод внешних штрафных функций</td>
#       <td id="T_442a5_row3_col4" class="data row3 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_442a5_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_442a5_row3_col7" class="data row3 col7" >1619</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_442a5_row4_col0" class="data row4 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row4_col1" class="data row4 col1" >[-1, -2]</td>
#       <td id="T_442a5_row4_col2" class="data row4 col2" >0.010000</td>
#       <td id="T_442a5_row4_col3" class="data row4 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_442a5_row4_col4" class="data row4 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_442a5_row4_col6" class="data row4 col6" >92</td>
#       <td id="T_442a5_row4_col7" class="data row4 col7" >20908</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_442a5_row5_col0" class="data row5 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row5_col1" class="data row5 col1" >[-1, -2]</td>
#       <td id="T_442a5_row5_col2" class="data row5 col2" >0.010000</td>
#       <td id="T_442a5_row5_col3" class="data row5 col3" >Метод внешних штрафных функций</td>
#       <td id="T_442a5_row5_col4" class="data row5 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_442a5_row5_col6" class="data row5 col6" >2</td>
#       <td id="T_442a5_row5_col7" class="data row5 col7" >1069</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_442a5_row6_col0" class="data row6 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row6_col1" class="data row6 col1" >[0, 0]</td>
#       <td id="T_442a5_row6_col2" class="data row6 col2" >0.010000</td>
#       <td id="T_442a5_row6_col3" class="data row6 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_442a5_row6_col4" class="data row6 col4" >[1.02, 1.04]</td>
#       <td id="T_442a5_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_442a5_row6_col6" class="data row6 col6" >10</td>
#       <td id="T_442a5_row6_col7" class="data row6 col7" >3051</td>
#     </tr>
#     <tr>
#       <th id="T_442a5_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_442a5_row7_col0" class="data row7 col0" >Функция Розенброка</td>
#       <td id="T_442a5_row7_col1" class="data row7 col1" >[0, 0]</td>
#       <td id="T_442a5_row7_col2" class="data row7 col2" >0.010000</td>
#       <td id="T_442a5_row7_col3" class="data row7 col3" >Метод внешних штрафных функций</td>
#       <td id="T_442a5_row7_col4" class="data row7 col4" >[1.0, 1.0]</td>
#       <td id="T_442a5_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_442a5_row7_col6" class="data row7 col6" >2</td>
#       <td id="T_442a5_row7_col7" class="data row7 col7" >862</td>
#     </tr>
#   </tbody>
# </table>

# %%
df3 = df3.sort_values('Начальная точка')

df3.style.set_caption('Результаты вычислений функции Розенброка в зависимости от начальной точки, alpha = 50').set_table_styles(styles)
# Out:
# <style type="text/css">
# #T_0faac caption {
#   text-align: center;
#   font-size: 150%;
# }
# </style>
# <table id="T_0faac">
#   <caption>Результаты вычислений функции Розенброка в зависимости от начальной точки, alpha = 50</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0faac_level0_col0" class="col_heading level0 col0" >Тип функции</th>
#       <th id="T_0faac_level0_col1" class="col_heading level0 col1" >Начальная точка</th>
#       <th id="T_0faac_level0_col2" class="col_heading level0 col2" >Точность</th>
#       <th id="T_0faac_level0_col3" class="col_heading level0 col3" >Метод</th>
#       <th id="T_0faac_level0_col4" class="col_heading level0 col4" >Точка минимума функции</th>
#       <th id="T_0faac_level0_col5" class="col_heading level0 col5" >Значение функции в точке минимума</th>
#       <th id="T_0faac_level0_col6" class="col_heading level0 col6" >Количество итераций</th>
#       <th id="T_0faac_level0_col7" class="col_heading level0 col7" >Количество вычислений функции</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0faac_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_0faac_row0_col0" class="data row0 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row0_col1" class="data row0 col1" >[-7, 0]</td>
#       <td id="T_0faac_row0_col2" class="data row0 col2" >0.000001</td>
#       <td id="T_0faac_row0_col3" class="data row0 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_0faac_row0_col4" class="data row0 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_0faac_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_0faac_row0_col7" class="data row0 col7" >1735</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_0faac_row1_col0" class="data row1 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row1_col1" class="data row1 col1" >[-7, 0]</td>
#       <td id="T_0faac_row1_col2" class="data row1 col2" >0.000001</td>
#       <td id="T_0faac_row1_col3" class="data row1 col3" >Метод внешних штрафных функций</td>
#       <td id="T_0faac_row1_col4" class="data row1 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_0faac_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_0faac_row1_col7" class="data row1 col7" >1735</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_0faac_row2_col0" class="data row2 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row2_col1" class="data row2 col1" >[-2, 2]</td>
#       <td id="T_0faac_row2_col2" class="data row2 col2" >0.000001</td>
#       <td id="T_0faac_row2_col3" class="data row2 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_0faac_row2_col4" class="data row2 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_0faac_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_0faac_row2_col7" class="data row2 col7" >2697</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_0faac_row3_col0" class="data row3 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row3_col1" class="data row3 col1" >[-2, 2]</td>
#       <td id="T_0faac_row3_col2" class="data row3 col2" >0.000001</td>
#       <td id="T_0faac_row3_col3" class="data row3 col3" >Метод внешних штрафных функций</td>
#       <td id="T_0faac_row3_col4" class="data row3 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_0faac_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_0faac_row3_col7" class="data row3 col7" >2697</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_0faac_row4_col0" class="data row4 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row4_col1" class="data row4 col1" >[0.1, 0.1]</td>
#       <td id="T_0faac_row4_col2" class="data row4 col2" >0.000001</td>
#       <td id="T_0faac_row4_col3" class="data row4 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_0faac_row4_col4" class="data row4 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_0faac_row4_col6" class="data row4 col6" >2</td>
#       <td id="T_0faac_row4_col7" class="data row4 col7" >1834</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_0faac_row5_col0" class="data row5 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row5_col1" class="data row5 col1" >[0.1, 0.1]</td>
#       <td id="T_0faac_row5_col2" class="data row5 col2" >0.000001</td>
#       <td id="T_0faac_row5_col3" class="data row5 col3" >Метод внешних штрафных функций</td>
#       <td id="T_0faac_row5_col4" class="data row5 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_0faac_row5_col6" class="data row5 col6" >2</td>
#       <td id="T_0faac_row5_col7" class="data row5 col7" >1834</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_0faac_row6_col0" class="data row6 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row6_col1" class="data row6 col1" >[4, 2.5]</td>
#       <td id="T_0faac_row6_col2" class="data row6 col2" >0.000001</td>
#       <td id="T_0faac_row6_col3" class="data row6 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_0faac_row6_col4" class="data row6 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_0faac_row6_col6" class="data row6 col6" >2</td>
#       <td id="T_0faac_row6_col7" class="data row6 col7" >1683</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_0faac_row7_col0" class="data row7 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row7_col1" class="data row7 col1" >[4, 2.5]</td>
#       <td id="T_0faac_row7_col2" class="data row7 col2" >0.000001</td>
#       <td id="T_0faac_row7_col3" class="data row7 col3" >Метод внешних штрафных функций</td>
#       <td id="T_0faac_row7_col4" class="data row7 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_0faac_row7_col6" class="data row7 col6" >2</td>
#       <td id="T_0faac_row7_col7" class="data row7 col7" >1683</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_0faac_row8_col0" class="data row8 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row8_col1" class="data row8 col1" >[5, 2]</td>
#       <td id="T_0faac_row8_col2" class="data row8 col2" >0.000001</td>
#       <td id="T_0faac_row8_col3" class="data row8 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_0faac_row8_col4" class="data row8 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_0faac_row8_col6" class="data row8 col6" >2</td>
#       <td id="T_0faac_row8_col7" class="data row8 col7" >1643</td>
#     </tr>
#     <tr>
#       <th id="T_0faac_level0_row9" class="row_heading level0 row9" >7</th>
#       <td id="T_0faac_row9_col0" class="data row9 col0" >Функция Розенброка</td>
#       <td id="T_0faac_row9_col1" class="data row9 col1" >[5, 2]</td>
#       <td id="T_0faac_row9_col2" class="data row9 col2" >0.000001</td>
#       <td id="T_0faac_row9_col3" class="data row9 col3" >Метод внешних штрафных функций</td>
#       <td id="T_0faac_row9_col4" class="data row9 col4" >[1.0, 1.0]</td>
#       <td id="T_0faac_row9_col5" class="data row9 col5" >0.000000</td>
#       <td id="T_0faac_row9_col6" class="data row9 col6" >2</td>
#       <td id="T_0faac_row9_col7" class="data row9 col7" >1643</td>
#     </tr>
#   </tbody>
# </table>

# %%
df4 = df4.sort_values('Метод')

df4.style.set_caption('Результаты вычислений функции Розенброка в зависимости от заданной точности, а = 50').set_table_styles(styles)
# Out:
# <style type="text/css">
# #T_dbda5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# </style>
# <table id="T_dbda5">
#   <caption>Результаты вычислений функции Розенброка в зависимости от заданной точности, а = 50</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbda5_level0_col0" class="col_heading level0 col0" >Тип функции</th>
#       <th id="T_dbda5_level0_col1" class="col_heading level0 col1" >Начальная точка</th>
#       <th id="T_dbda5_level0_col2" class="col_heading level0 col2" >Точность</th>
#       <th id="T_dbda5_level0_col3" class="col_heading level0 col3" >Метод</th>
#       <th id="T_dbda5_level0_col4" class="col_heading level0 col4" >Точка минимума функции</th>
#       <th id="T_dbda5_level0_col5" class="col_heading level0 col5" >Значение функции в точке минимума</th>
#       <th id="T_dbda5_level0_col6" class="col_heading level0 col6" >Количество итераций</th>
#       <th id="T_dbda5_level0_col7" class="col_heading level0 col7" >Количество вычислений функции</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbda5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dbda5_row0_col0" class="data row0 col0" >Функция Розенброка</td>
#       <td id="T_dbda5_row0_col1" class="data row0 col1" >[-1, -2]</td>
#       <td id="T_dbda5_row0_col2" class="data row0 col2" >0.010000</td>
#       <td id="T_dbda5_row0_col3" class="data row0 col3" >Метод внешних штрафных функций</td>
#       <td id="T_dbda5_row0_col4" class="data row0 col4" >[1.0, 1.0]</td>
#       <td id="T_dbda5_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_dbda5_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_dbda5_row0_col7" class="data row0 col7" >1569</td>
#     </tr>
#     <tr>
#       <th id="T_dbda5_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_dbda5_row1_col0" class="data row1 col0" >Функция Розенброка</td>
#       <td id="T_dbda5_row1_col1" class="data row1 col1" >[-1, -2]</td>
#       <td id="T_dbda5_row1_col2" class="data row1 col2" >0.000001</td>
#       <td id="T_dbda5_row1_col3" class="data row1 col3" >Метод внешних штрафных функций</td>
#       <td id="T_dbda5_row1_col4" class="data row1 col4" >[1.0, 1.0]</td>
#       <td id="T_dbda5_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_dbda5_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_dbda5_row1_col7" class="data row1 col7" >1950</td>
#     </tr>
#     <tr>
#       <th id="T_dbda5_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_dbda5_row2_col0" class="data row2 col0" >Функция Розенброка</td>
#       <td id="T_dbda5_row2_col1" class="data row2 col1" >[-1, -2]</td>
#       <td id="T_dbda5_row2_col2" class="data row2 col2" >0.010000</td>
#       <td id="T_dbda5_row2_col3" class="data row2 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_dbda5_row2_col4" class="data row2 col4" >[1.0, 1.0]</td>
#       <td id="T_dbda5_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_dbda5_row2_col6" class="data row2 col6" >81</td>
#       <td id="T_dbda5_row2_col7" class="data row2 col7" >18376</td>
#     </tr>
#     <tr>
#       <th id="T_dbda5_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_dbda5_row3_col0" class="data row3 col0" >Функция Розенброка</td>
#       <td id="T_dbda5_row3_col1" class="data row3 col1" >[-1, -2]</td>
#       <td id="T_dbda5_row3_col2" class="data row3 col2" >0.000001</td>
#       <td id="T_dbda5_row3_col3" class="data row3 col3" >Метод внутренних штрафных функций</td>
#       <td id="T_dbda5_row3_col4" class="data row3 col4" >[1.0, 1.0]</td>
#       <td id="T_dbda5_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_dbda5_row3_col6" class="data row3 col6" >81</td>
#       <td id="T_dbda5_row3_col7" class="data row3 col7" >18580</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <H2> Plots </H2>

# %%
e_help = 2
eps = 10**(-e_help)

x0 = [-5, 5]

#foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
foo = lambda x, y: 5*x**2 + 4* x * y + 2 * y**2 + 4 * math.sqrt(5) * (x +  y) -35
print_res(foo, x0, 6, 0)
print_res(foo, x0, 6, 1)


alpha = 5
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
#foo = lambda x, y: 6*x**2 - 4* x * y + 3 * y**2 + 4 * math.sqrt(5) * (x +  2*y) +22
print_res(foo, x0, 6, 0)
print_res(foo, x0, 6, 1)


alpha = 50
foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
#foo = lambda x, y: 6*x**2 - 4* x * y + 3 * y**2 + 4 * math.sqrt(5) * (x +  2*y) +22
print_res(foo, x0, 6, 0)
print_res(foo, x0, 6, 1)


# alpha = 20

# foo = lambda x, y: alpha * (x**2 - y)**2 + (x - 1)**2
# print_res(foo, x0, 6, 1, 1)

#foo = lambda x, y: 6*x**2 - 4* x * y + 3 * y**2 + 4 * math.sqrt(5) * (x +  2*y) +22

#foo = lambda x, y: 10*x**2 - 4* x * y + 7 * y**2 - 4 * math.sqrt(5) * (5*x - y) -16
# Out:
#                                 Методы штрафных функций
#
# Дано:
# ------------------------
#       Целевая функция:    f(x, y) = 5*x**2 + 4*x*y + 8.94427190999916*x + 2*y**2 + 8.94427190999916*y - 35
# Начальное приближение:    (x, y) = [-5, 5]
#  Точность приближения:    eps = 1e-06
# ------------------------
#
#                                 Метод внутренних штрафных функций
#
#
#                                 на можестве A
#
#              Точка минимума функции:     x_min = [0.0, 0.0]
#   Значение функции в точке минимума:  f(x_min) = -35.0
#                 Количество итераций:         k = 283
#       Количество вычислений функции:       n_f = 60381
#                                 Метод внешних штрафных функций
#
#
#                                 на можестве A
#
#              Точка минимума функции:     x_min = [0.0, 0.0]
#   Значение функции в точке минимума:  f(x_min) = -35.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 704
#                                 Методы штрафных функций
#
# Дано:
# ------------------------
#       Целевая функция:    f(x, y) = 5*x**2 + 4*x*y + 8.94427190999916*x + 2*y**2 + 8.94427190999916*y - 35
# Начальное приближение:    (x, y) = [-5, 5]
#  Точность приближения:    eps = 1e-06
# ------------------------
#
#                                 Метод внутренних штрафных функций
#
#
#                                 на множестве B
#
#              Точка минимума функции:     x_min = [0.0, -2.236068]
#   Значение функции в точке минимума:  f(x_min) = -45.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 613
#                                 Метод внешних штрафных функций
#
#
#                                 на множестве B
#
#              Точка минимума функции:     x_min = [0.0, -2.236068]
#   Значение функции в точке минимума:  f(x_min) = -45.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 616
#                                 Методы штрафных функций
#
# Дано:
# ------------------------
#       Целевая функция:    f(x, y) = (x - 1)**2 + 5*(x**2 - y)**2
# Начальное приближение:    (x, y) = [-5, 5]
#  Точность приближения:    eps = 1e-06
# ------------------------
#
#                                 Метод внутренних штрафных функций
#
#
#                                 на можестве A
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 283
#       Количество вычислений функции:       n_f = 62436
#                                 Метод внешних штрафных функций
#
#
#                                 на можестве A
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 3
#       Количество вычислений функции:       n_f = 2084
#                                 Методы штрафных функций
#
# Дано:
# ------------------------
#       Целевая функция:    f(x, y) = (x - 1)**2 + 5*(x**2 - y)**2
# Начальное приближение:    (x, y) = [-5, 5]
#  Точность приближения:    eps = 1e-06
# ------------------------
#
#                                 Метод внутренних штрафных функций
#
#
#                                 на множестве B
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 1831
#                                 Метод внешних штрафных функций
#
#
#                                 на множестве B
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 1831
#                                 Методы штрафных функций
#
# Дано:
# ------------------------
#       Целевая функция:    f(x, y) = (x - 1)**2 + 50*(x**2 - y)**2
# Начальное приближение:    (x, y) = [-5, 5]
#  Точность приближения:    eps = 1e-06
# ------------------------
#
#                                 Метод внутренних штрафных функций
#
#
#                                 на можестве A
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 289
#       Количество вычислений функции:       n_f = 67095
#                                 Метод внешних штрафных функций
#
#
#                                 на можестве A
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 2793
#                                 Методы штрафных функций
#
# Дано:
# ------------------------
#       Целевая функция:    f(x, y) = (x - 1)**2 + 50*(x**2 - y)**2
# Начальное приближение:    (x, y) = [-5, 5]
#  Точность приближения:    eps = 1e-06
# ------------------------
#
#                                 Метод внутренних штрафных функций
#
#
#                                 на множестве B
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 3068
#                                 Метод внешних штрафных функций
#
#
#                                 на множестве B
#
#              Точка минимума функции:     x_min = [1.0, 1.0]
#   Значение функции в точке минимума:  f(x_min) = 0.0
#                 Количество итераций:         k = 2
#       Количество вычислений функции:       n_f = 3068

# %% [markdown]
# <H1> Выводы </H1>

# %% [markdown]
# В лабораторной работе были рассмотрены флгоритмы прямого поиска, в которых используется информация только о значениях функции.
#
# Достоинством данных методов является то, что нам не требуется дифференцируемость функции. Однако из-за этого появляются и недостатки:
# трудность с оценкой эффективности методов и их точность.
# Метод покоординатного спуска является самым простым для реализации, однако его простота делает его не самым эффективным по количеству вычислений функции. Методы Хука-Дживса и Розенброка является эффективнее по данному параметру. Наиболее выгодным является метод Хука-Дживса.
# Следует отметить, что при сильно овражной функции и маленькой точности методы ПС и Хука-Дживса ищут минимум не точно. Для точного поиска
# (методом Розенброка) следует жертвовать производительностью.
